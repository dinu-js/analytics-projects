# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
calHousing = pd.read_csv('california-housing.csv')
calHousing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300
# 4         565         259         3.8462        NEAR BAY              342200

# %%
calHousing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
calHousing.shape
# Out:
# (20640, 10)

# %%
calHousing.size
# Out:
# 206400

# %%
cols = calHousing.columns.to_list()
cols
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'ocean_proximity',
#  'median_house_value']

# %% [markdown]
# Summary Statistics for Categoric and Numeric Columns

# %%
#list of numeric cols
num = calHousing.select_dtypes(include=np.number).columns.to_list()
num
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value']

# %%
#list of categorical cols
cat = calHousing.select_dtypes(exclude=np.number).columns.to_list()
cat
# Out:
# ['ocean_proximity']

# %%
calHousing[num].describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
calHousing[cat].describe()
# Out:
#        ocean_proximity
# count            20640
# unique               5
# top          <1H OCEAN
# freq              9136

# %% [markdown]
# Checking null values

# %%
calHousing.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %% [markdown]
# Treating null value

# %%
calHousing['total_bedrooms'].isna().sum()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
calHousing['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
ma=round(calHousing.groupby(['ocean_proximity'])['total_bedrooms'].mean()[1],0)
ma
# Out:
# 534.0

# %%
calHousing["total_bedrooms"]=calHousing["total_bedrooms"].fillna(ma)

# %%
calHousing['total_bedrooms'].isna().sum()
# Out:
# 0

# %% [markdown]
# Removing unwanted cols

# %%
cols
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'ocean_proximity',
#  'median_house_value']

# %%
calHousing.drop(['longitude','latitude'],axis=1,inplace=True)

# %%
calHousing
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                      41          880           129.0         322
# 1                      21         7099          1106.0        2401
# 2                      52         1467           190.0         496
# 3                      52         1274           235.0         558
# 4                      52         1627           280.0         565
# ...                   ...          ...             ...         ...
# 20635                  25         1665           374.0         845
# 20636                  18          697           150.0         356
# 20637                  17         2254           485.0        1007
# 20638                  18         1860           409.0         741
# 20639                  16         2785           616.0        1387
#
#        households  median_income ocean_proximity  median_house_value
# 0             126         8.3252        NEAR BAY              452600
# ...

# %%
columns = calHousing.columns.to_list()
columns
# Out:
# ['housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'ocean_proximity',
#  'median_house_value']

# %%
col1 = ['housing_median_age',
 'total_rooms',
 'total_bedrooms',
 'population',
 'households',
 'median_income',
 'median_house_value']
col1
# Out:
# ['housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value']

# %% [markdown]
# Visualization

# %%
for i in columns:
    sns.histplot(calHousing[i])
    plt.show()

# %%
#distribution plots
for i in col1:
    sns.distplot(calHousing[i])
    plt.show()
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_32288\3815789140.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(calHousing[i])
# C:\Users\dines\AppData\Local\Temp\ipykernel_32288\3815789140.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(calHousing[i])
# ...

# %%
calHousing[cat].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN          9136
# INLAND             6551
# NEAR OCEAN         2658
# NEAR BAY           2290
# ISLAND                5
# Name: count, dtype: int64

# %%
sns.countplot(x=calHousing["ocean_proximity"])
plt.show()

# %%
#Removing the outliers: as ocean data is very less
calHousingFinal = calHousing[calHousing['ocean_proximity'] != 'ISLAND']

# %%
calHousing
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                      41          880           129.0         322
# 1                      21         7099          1106.0        2401
# 2                      52         1467           190.0         496
# 3                      52         1274           235.0         558
# 4                      52         1627           280.0         565
# ...                   ...          ...             ...         ...
# 20635                  25         1665           374.0         845
# 20636                  18          697           150.0         356
# 20637                  17         2254           485.0        1007
# 20638                  18         1860           409.0         741
# 20639                  16         2785           616.0        1387
#
#        households  median_income ocean_proximity  median_house_value
# 0             126         8.3252        NEAR BAY              452600
# ...

# %%
scatter = ['households','total_rooms','total_bedrooms']

# %%
for i in scatter:
    sns.scatterplot(x=calHousing[i],y=calHousing['population'])
    plt.show()

# %% [markdown]
# Multivariate

# %%
col1
# Out:
# ['housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value']

# %%
sns.heatmap(calHousing[col1].corr(),annot=True)
plt.show()

# %% [markdown]
# 1) The columns total_rooms, total_bedrooms, population, household are the columns which are highly correlated
# 2) This can be reduces by using Variance Inflation Factor(VIF)
# 3) The column median_income has good coorlation with target
#
# TBD - linear regression
